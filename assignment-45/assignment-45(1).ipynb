# %%
import pandas as pd

# %%
# Import the necessary libraries and load the dataset into Pandas DataFrame
house_price=pd.read_csv("C://Users//chand//OneDrive//Documents//learn//git//fullstack_python//assignment-45//HousePrices_dataset.csv")

# %%
house_price
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#Perform basic data exploration and data cleaning if necessar
house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
house_price.size
# Out:
# 82800

# %%
house_price.shape
# Out:
# (4600, 18)

# %%
house_price.isnull().count
# Out:
# <bound method DataFrame.count of        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
# Calculate the average house price using .mean()
avg_price=house_price['price'].mean()
avg_price=round(avg_price,2)
avg_price
print(f" Average price is : {avg_price}")
# Out:
#  Average price is : 551962.99

# %%
#Find the most common number of bedrooms 
common_bedroom=house_price['bedrooms'].mode()
print(f" common bedroom is : {common_bedroom}")
# Out:
#  common bedroom is : 0    3
# Name: bedrooms, dtype: int64

# %%
# find the most common bathrooms
common_bathroom= house_price['bathrooms'].mode()
print(f" common bathroom is : {common_bathroom}")
# Out:
#  common bathroom is : 0    2.5
# Name: bathrooms, dtype: float64

# %%
#Identify any correlation between the house price and other numeric features (e.g., sqft_living, waterfront, and view) using .corr() functions
correlation= house_price['price'].corr(house_price['sqft_living'])
correlation= round(correlation,2)
correlation
print(f" correlation is {correlation} , It is moderate positive relation")
# Out:
#  correlation is 0.43 , It is moderate positive relation

# %%
#correlation between price and waterfront
correlation=house_price['price'].corr(house_price['waterfront'])
correlation=round(correlation,2)
correlation
print(f" correlation is {correlation}, it is weak positive correlation")
# Out:
#  correlation is 0.14, it is weak positive correlation

# %%
#correlation betweem price and view
correlation=house_price['price'].corr(house_price['view'])
correlation=round(correlation,2)
correlation
print(f" correlation is {correlation}: It is weak positive correlation")
# Out:
#  correlation is 0.23: It is weak positive correlation

# %%
#Calculate the average price of non-waterfront houses
average_price = house_price[house_price['waterfront'] == 0]['price'].mean()
average_price=round(average_price,2)
print(f"Average price of non-waterfront houses is : {average_price}")
# Out:
# Average price of non-waterfront houses is : 545462.28

# %%
# calculate the average price of waterfront houses
average_price=house_price[house_price['waterfront']==1]['price'].mean()
average_price=round(average_price,2)
print(f"average price of waterfront houses is : {average_price}")
# Out:
# average price of waterfront houses is : 1451621.21

# %%
#Determine the average price of houses with different numbers of floor
avg_price_by_floors = house_price.groupby('floors')['price'].mean()
avg_price_by_floors = round(avg_price_by_floors,2)
print(f" Average price of houses with diff. number of floor is : {avg_price_by_floors}")
# Out:
#  Average price of houses with diff. number of floor is : floors
# 1.0    457278.69
# 1.5    578692.70
# 2.0    647985.23
# 2.5    983863.39
# 3.0    566157.59
# 3.5    829250.00
# Name: price, dtype: float64

# %%
#Analyze the average price based on the house condition
avg_price_by_condition=house_price.groupby('condition')['price'].mean()
avg_price_by_condition =round(avg_price_by_condition,2)
print(f"Average price on condition is : {avg_price_by_condition}")
# Out:
# Average price on condition is : condition
# 1    306633.33
# 2    324373.75
# 3    550111.52
# 4    533647.29
# 5    637041.32
# Name: price, dtype: float64

# %%
#A histogram showing the distribution of house prices using .plot()
house_price['price'].plot(kind='hist',title='DISTRIBUTION OF HOUSES')
# Out:
# <Axes: title={'center': 'DISTRIBUTION OF HOUSES'}, ylabel='Frequency'>

# %%
#Scatter plots to visualize the relationships between price and other numeric features using .plot()
house_price.plot(kind='scatter',x='sqft_living', y='price',title='PRICE VS SQUARE FOOT')
# Out:
# <Axes: title={'center': 'PRICE VS SQUARE FOOT'}, xlabel='sqft_living', ylabel='price'>

# %%
house_price.plot(kind='scatter',x='waterfront',y='price', title= 'PRICE VS WATERFRONT')
# Out:
# <Axes: title={'center': 'PRICE VS WATERFRONT'}, xlabel='waterfront', ylabel='price'>

# %%
house_price.plot(kind='scatter',x='view',y='price',title='PRICE VS VIEW')
# Out:
# <Axes: title={'center': 'PRICE VS VIEW'}, xlabel='view', ylabel='price'>

# %%
#A bar graph to count the occurrences of each city
house_price['city'].value_counts().plot(kind='bar',title='NUMBER OF LISTING PER CITY',figsize=(15,5))
# Out:
# <Axes: title={'center': 'NUMBER OF LISTING PER CITY'}, xlabel='city'>
