# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#Load the Titanic dataset from a CSV file
titanic=pd.read_csv("C://Users//chand//OneDrive//Documents//learn//git//fullstack_python//assignment-49//titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Conduct exploratory data analysis using methods such as head(), tail(), describe(), and dtypes to examine the dataset
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Handle data indexing and manipulation using df.iloc[] and df.loc[] to access specific rows in the DataFrame
titanic.loc[titanic['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic.iloc[:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
titanic.query('Age > 40')
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 391         1283         1       1
# 393         1285         0       2
# 397         1289         1       1
# 404         1296         0       1
# 407         1299         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Filter the dataset based on specific conditions and save the resulting data
#how many people survived
df=(pd.read_csv("C://Users//chand//OneDrive//Documents//learn//git//fullstack_python//assignment-49//titanic.csv").query('Survived == 1')
        .to_csv('survived.csv'))

# %%
# read df
df=pd.read_csv('survived.csv')

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             1          893         1       3
# 1             4          896         1       3
# 2             6          898         1       3
# 3             8          900         1       3
# 4            12          904         1       1
# ..          ...          ...       ...     ...
# 147         409         1301         1       3
# 148         410         1302         1       3
# 149         411         1303         1       1
# 150         412         1304         1       3
# 151         414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 1       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 2                               Connolly, Miss. Kate  female  30.0      0
# 3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# ...

# %%
#Optimize memory usage by converting column data types
titanic['Name']=titanic['Name'].astype('string')

# %%
titanic['Sex']=titanic['Sex'].astype('category')

# %%
titanic['Embarked']=titanic['Embarked'].astype('category')

# %%
titanic.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    string
#  4   Sex          418 non-null    category
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    category
# dtypes: category(2), float64(2), int64(5), object(2), string(1)
# memory usage: 93.2 KB

# %%
#Handle missing data
#count null value
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#drop null column
titanic.drop('Cabin',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# fill age null value with 0
titanic['Age'] = titanic['Age'].fillna(0)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Preprocess the data by extracting useful features and applying feature
#age column split by ','
titanic=pd.read_csv("C://Users//chand//OneDrive//Documents//learn//git//fullstack_python//assignment-49//titanic.csv")
titanic['Name']=titanic['Name'].apply(lambda x: x.split(',')[0])
titanic
# Out:
#      PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0            892         0       3          Kelly    male  34.5      0      0
# 1            893         1       3         Wilkes  female  47.0      1      0
# 2            894         0       2          Myles    male  62.0      0      0
# 3            895         0       3           Wirz    male  27.0      0      0
# 4            896         1       3       Hirvonen  female  22.0      1      1
# ..           ...       ...     ...            ...     ...   ...    ...    ...
# 413         1305         0       3        Spector    male   NaN      0      0
# 414         1306         1       1  Oliva y Ocana  female  39.0      0      0
# 415         1307         0       3        Saether    male  38.5      0      0
# 416         1308         0       3           Ware    male   NaN      0      0
# 417         1309         0       3          Peter    male   NaN      1      1
#
# ...

# %%
#Normalize data using the Min-Max scaling technique
titanic['Age']=(df['Age'] - df['Age'].min() ) / (df['Age'].max() - df['Age'].min())

# %%
titanic['Age']
# Out:
# 0      0.617566
# 1      0.287881
# 2      0.393380
# 3      0.235131
# 4      0.301068
#          ...
# 413         NaN
# 414         NaN
# 415         NaN
# 416         NaN
# 417         NaN
# Name: Age, Length: 418, dtype: float64

# %%
#Conduct aggregate analysis using group-by operations 
titanic
# Out:
#      PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0            892         0       3          Kelly    male  34.5      0      0
# 1            893         1       3         Wilkes  female  47.0      1      0
# 2            894         0       2          Myles    male  62.0      0      0
# 3            895         0       3           Wirz    male  27.0      0      0
# 4            896         1       3       Hirvonen  female  22.0      1      1
# ..           ...       ...     ...            ...     ...   ...    ...    ...
# 413         1305         0       3        Spector    male   NaN      0      0
# 414         1306         1       1  Oliva y Ocana  female  39.0      0      0
# 415         1307         0       3        Saether    male  38.5      0      0
# 416         1308         0       3           Ware    male   NaN      0      0
# 417         1309         0       3          Peter    male   NaN      1      1
#
# ...

# %%
titanic.groupby(['Sex']).count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          152       152     152   152  127    152    152     152   152
# male            266       266     266   266  205    266    266     266   265
#
#         Cabin  Embarked
# Sex
# female     44       152
# male       47       266

# %%
#visualize the data using basic plotting techniques
titanic['Age'].plot()
# Out:
# <Axes: >

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
plt.hist(titanic['Age'],bins=20)
plt.title("AGE DISTRIBUTION")
plt.show()

# %%
# age vs fare
plt.scatter(titanic['Age'], titanic['Fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
plt.bar(titanic['Sex'],titanic['Survived'])
plt.show()
